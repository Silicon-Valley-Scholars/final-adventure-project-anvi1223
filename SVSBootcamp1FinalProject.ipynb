# %%
import math
import time
print("You wake up in a dark room!")
print("Not remembering a single thing.")
name = input("Choose your name: ")
print(f"Welcome, {name}!")
print("You exit out of the room and see a long hallway.")
print("You see two different weapons: a dagger and a sword.")

gold = 0
weapon = input("Choose your weapon (dagger/sword): ").lower()

if weapon == "dagger":
    print("Good choice! But you should sharpen your dagger on a rock before continuing.")
elif weapon == "sword":
    print("Good choice! But you should sharpen your sword on a rock before continuing.")
else:
    print("You hesitated and chose nothing... Danger might lie ahead unarmed.")

print("You hear a strange noise going...")
print("Drip, drip, drip")
print("Then, you found out the hallway was a dead end. ")
print("But you see a left and right pathway! ")
pathway = input("Which do you choose (left/right)? ").lower()

if pathway == "left":
    print("You see small, baby animals, so you decide to choose one as a companion!")
else:
    print("A mysterious wind comes and pushes you towards the left side!")
    print("You see small, baby animals, so you decide to choose one as a companion!")

companion = input("Which do you choose (kitten/puppy/baby tiger)? ").lower()

if companion == "kitten":
    companion_name = input("Great! Your kitten needs a name. What will you name it? ")
elif companion == "puppy":
    companion_name = input("Great! Your puppy needs a name. What will you name it? ")
elif companion == "baby tiger":
    companion_name = input("Great! Your baby tiger needs a name. What will you name it? ")
else:
    print("You don't like pet animals, but you realize a rat has been following you the entire way!")
    companion = "rat"
    companion_name = input("Your rat needs a name. What will you name it? ")

x = 25
y = 25
z = 50
print("You found ", x, " gold in your pocket! ")
print("And ", y, " gold on the floor while coming here! ")
print("Your pet had", z, "gold in it's pocket")
print("You now have ", x+y+z, " gold!")
gold = 100

print("You see a door and think am I finally done, but when you try to open the door it's locked. ")
print("You see a puzzle on the wall with the numbers 24, 16, -7, 9, -1.")
print("You realize they want you to find the minimum of the puzzle.")
math = min(24, 16, -7, 9, -1)
print("You find the answer", math," and the door unlocks.")
print("You think to yourself is that what I think it is ")
#sleep
print(" a ")
time.sleep(25)
print(" SPIDER!")
print("You are frightened, but realize the spider is blocking a door. ")
#list
choices = {"You can defeat the spider with your weapon and companion ", "You can try talking to the spider ", " You can do parkor around the spider to the door"}
for each in choices:
  print(" - ", each)
print("The spider grabs you by your hand... ")
print("You think your life is over and start counting down your last seconds while saying goodbye to your fellow companion.")
print("You have served me well companion!")
#loop
d = 1
while d<=3:
  print(d)
  d += 1
print("Why am I not dead yet you thought? ")
print("Then the spider gives you a big hug!")
print("And says, Thank you for saving my nephew! ")
print("This is your nephew ? ")
print("As you can see ... ")
print("This ", companion, "is my nephew. ")
print("Who I have to take care of since it's mother and father died.")
print("We live here to hide from the other creatures out in the real world , but we never went exploring in this cave because this ", companion,  "is scared of the dark.")
print("But now that you have found it I am so happy and grateful for you being here.")
print("Thank you so very very much.")
print("Here is the door leading out to the real world. ")
print("You walk to the door and open it. ")
print("As you walk out you feel a breeze of nice air!")

# function
def ending(name, companion_name):
  return "You have finished the challenge "+name+" along with your companion, "+companion_name+" !"

print(ending(name, companion_name))
# Out:
# You wake up in a dark room!
# Not remembering a single thing.
# Choose your name: gg
# Welcome, gg!
# You exit out of the room and see a long hallway.
# You see two different weapons: a dagger and a sword.
# Choose your weapon (dagger/sword): gg
# You hesitated and chose nothing... Danger might lie ahead unarmed.
# You hear a strange noise going...
# Drip, drip, drip
# Then, you found out the hallway was a dead end.
# But you see a left and right pathway!
# Which do you choose (left/right)? gg
# A mysterious wind comes and pushes you towards the left side!
# You see small, baby animals, so you decide to choose one as a companion!
# Which do you choose (kitten/puppy/baby tiger)? gg
# You don't like pet animals, but you realize a rat has been following you the entire way!
# Your rat needs a name. What will you name it? gg
# You found  25  gold in your pocket!
# And  25  gold on the floor while coming here!
# Your pet had 50 gold in it's pocket
# You now have  100  gold!
# ...
